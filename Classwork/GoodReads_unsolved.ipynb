# %%
# Import Dependencies
import pandas as pd

# %%
# Make a reference to the books.csv file path
file_to_load = "Resources/books.csv"
# Import the books.csv file as a DataFrame with utf-8 encoding.
books_df = pd.read_csv(file_to_load)

# %%
#  Get the data types of each column.
books_df.dtypes
# Out:
# id                             int64
# book_id                        int64
# best_book_id                   int64
# work_id                        int64
# books_count                    int64
# isbn                          object
# isbn13                       float64
# authors                       object
# original_publication_year    float64
# original_title                object
# title                         object
# language_code                 object
# average_rating               float64
# ratings_count                  int64
# work_ratings_count             int64
# work_text_reviews_count        int64
# ratings_1                      int64
# ratings_2                      int64
# ratings_3                      int64
# ratings_4                      int64
# ratings_5                      int64
# image_url                     object
# small_image_url               object
# dtype: object

# %%
# Get a list of all columns within the DataFrame
books_df.columns.tolist()
# Out:
# ['id',
#  'book_id',
#  'best_book_id',
#  'work_id',
#  'books_count',
#  'isbn',
#  'isbn13',
#  'authors',
#  'original_publication_year',
#  'original_title',
#  'title',
#  'language_code',
#  'average_rating',
#  'ratings_count',
#  'work_ratings_count',
#  'work_text_reviews_count',
#  'ratings_1',
#  'ratings_2',
#  'ratings_3',
#  'ratings_4',
#  'ratings_5',
#  'image_url',
#  'small_image_url']

# %%
# Remove unecessary columns from the DataFrame and save the new DataFrame
# Only keep: "isbn", "original_publication_year", "original_title", "authors", "ratings_1", "ratings_2", "ratings_3", "ratings_4", "ratings_5"
new_books_df = books_df[["isbn", "original_publication_year", "original_title", "authors", "ratings_1", "ratings_2", "ratings_3", "ratings_4", "ratings_5"]].copy()
new_books_df
# Out:
#             isbn  original_publication_year  \
# 0      439023483                     2008.0
# 1      439554934                     1997.0
# 2      316015849                     2005.0
# 3       61120081                     1960.0
# 4      743273567                     1925.0
# ...          ...                        ...
# 9995   441019455                     2010.0
# 9996  067973371X                     1990.0
# 9997  039330762X                     1977.0
# 9998    61711527                     2011.0
# 9999   375700455                     1998.0
#
#                                          original_title  \
# 0                                      The Hunger Games
# 1              Harry Potter and the Philosopher's Stone
# 2                                              Twilight
# 3                                 To Kill a Mockingbird
# 4                                      The Great Gatsby
# ...                                                 ...
# ...

# %%
# Rename the headers to be more explanatory
new_books_df.renamed
